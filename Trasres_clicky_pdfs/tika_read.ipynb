# %% [markdown]
# ## read

# %%
from tika import parser
raw = parser.from_file("Data/www.trasers.com » Actions - 2019-08-22.pdf")
print(raw['content'])
# Out:
# www.trasers.com » Actions - 2019-08-22
#
# Visitor detail
#
# Visits: 5
#
# Unique ID: 2749500497
#
# IP address: 67.188.228.0 - ARIN  RIPE
#
# Locale:  Redwood City, California, USA / English
#
# Organization:  Comcast Cable / comcast.net
#
# Platform:  Google Chrome 75.0    Mac OS X
#
# 1440x900
#
# All time goals:  Main Register Step 1 (Aug 22 2019)
#
#  This visit  First visit
#
# Date: Wed Aug 14 2019, 9:14am You are currently viewing this person's first visit.
#
# Session: 10m 20s, 3 actions
#
# Landing page:  /blog/technology
#
# Referrer:  google.com [secure search]
#
#  Searches
#
# Aug 14 2019
#
# 9:14:12 am
#
#  /blog/technology
#
# Technology Transformation Blogs | TRASERS
#
# Aug 14 2019
#
# 9:14:20 am
#
#  /insights
#
# Market Research Industry Insights for Enterprises
#
# Aug 14 2019
#
# 9:14:32 am
#
#  /insights/be-proactive-or-perish-the-transformation-tsunami-will-be-merciless-on-laggards
#
# ...

# %%
from tika import parser

file = 'Data/www.trasers.com » Actions - 2019-08-22.pdf'
# Parse data from file
file_data = parser.from_file(file)
# Get files text content
text = file_data['content']
print(text)
# Out:
# www.trasers.com » Actions - 2019-08-22
#
# Visitor detail
#
# Visits: 5
#
# Unique ID: 2749500497
#
# IP address: 67.188.228.0 - ARIN  RIPE
#
# Locale:  Redwood City, California, USA / English
#
# Organization:  Comcast Cable / comcast.net
#
# Platform:  Google Chrome 75.0    Mac OS X
#
# 1440x900
#
# All time goals:  Main Register Step 1 (Aug 22 2019)
#
#  This visit  First visit
#
# Date: Wed Aug 14 2019, 9:14am You are currently viewing this person's first visit.
#
# Session: 10m 20s, 3 actions
#
# Landing page:  /blog/technology
#
# Referrer:  google.com [secure search]
#
#  Searches
#
# Aug 14 2019
#
# 9:14:12 am
#
#  /blog/technology
#
# Technology Transformation Blogs | TRASERS
#
# Aug 14 2019
#
# 9:14:20 am
#
#  /insights
#
# Market Research Industry Insights for Enterprises
#
# Aug 14 2019
#
# 9:14:32 am
#
#  /insights/be-proactive-or-perish-the-transformation-tsunami-will-be-merciless-on-laggards
#
# ...

# %%
from tika import parser 
parsedPDF = parser.from_file("Data/www.trasers.com » Actions - 2019-08-22.pdf")

# %%
parsedPDF.keys()
# Out:
# dict_keys(['status', 'content', 'metadata'])

# %%
parsedPDF["content"]
# Out:
# "\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nwww.trasers.com » Actions - 2019-08-22\n\nVisitor detail\n\nVisits: 5\n\nUnique ID: 2749500497\n\nIP address: 67.188.228.0 - ARIN  RIPE \n\nLocale:  Redwood City, California, USA / English\n\nOrganization:  Comcast Cable / comcast.net\n\nPlatform:  Google Chrome 75.0 \xa0  Mac OS X \xa0\n\n1440x900 \xa0\n\nAll time goals:  Main Register Step 1 (Aug 22 2019)\n\n This visit  First visit\n\nDate: Wed Aug 14 2019, 9:14am You are currently viewing this person's first visit.\n\nSession: 10m 20s, 3 actions\n\nLanding page:  /blog/technology\n\nReferrer:  google.com [secure search]\n\n Searches\n\nAug 14 2019\n\n9:14:12 am\n\n /blog/technology\n\nTechnology Transformation Blogs | TRASERS\n\nAug 14 2019\n\n9:14:20 am\n\n /insights\n\nMarket Research Industry Insights for Enterprises\n\nAug 14 2019\n\n9:14:32 am\n\n /insights/be-proactive-or-perish-the-transformation-tsunami-will-be-merciless-on-laggards\n\nBe Proacti
# ...
