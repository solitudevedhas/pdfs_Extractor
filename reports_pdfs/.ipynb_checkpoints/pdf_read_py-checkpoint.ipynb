# %%
from tabula import read_pdf
from tabulate import tabulate
import pandas as pd

# %%
pdf_contents = read_pdf("Report_1600821.pdf", pages="all", multiple_tables=True)

# %%
pdf_content = pdf_contents
pdf_content.pop(0)
pdf_content.pop(60)
# Out:
#                           0  \
# 0                       NaN
# 1             Import Action
# 2                    UPDATE
# 3  Total Suppliers Imported
#
#                                                    1                   2  \
# 0                                                NaN  Suppliers Imported
# 1                                           Supplier                 NaN
# 2  Mark W LaChey dba Law Office of Mark W LaChey-...                 NaN
# 3                                                  1                 NaN
#
#                  3
# 0              NaN
# 1  Supplier Number
# 2         ab:87961
# 3              NaN

# %%
report_df = pd.DataFrame()
for i in range(len(pdf_content)):
    page = pdf_content[i]
    page = page.drop(page.index[:2])
    page = page.drop([1,3,5], axis=1)
    report_df = pd.concat([report_df, page])

# %%
report_df = report_df.rename(columns={0:'Interface ID',2 : 'Supplier', 4 : 'Rejection Reason' , 6 : ' Value'})

# %%
report_df
# Out:
#                        Interface ID  \
# 2                              9936
# 3                              9848
# 4                              9628
# 5                              9891
# 6                              9618
# 7                              9763
# 8                              9640
# 9                              9528
# 10                             9938
# 11                             9345
# 12                             9748
# 13                            10071
# 14                             9578
# 15                            10107
# 2                             12227
# 3                             10030
# 4                              9772
# 5                              9812
# 6                             10148
# 7                              9592
# 8                              9977
# 9                              9493
# 10                             9426
# 11                             9973
# 12                             9702
# 13                             9497
# 14                             9717
# 15                             9430
# 16                             9985
# 17                             9390
# ..                              ...
# 11                             9596
# 12                             9863
# 13                             9988
# 14                             9852
# 15                             9664
# 16                             9406
# 17                            10122
# 2                               NaN
# 3                              9665
# 4                              9510
# 5                              9274
# 6                              9594
# 7                              9632
# 8                              9909
# 9                              9399
# 10                             9312
# 11                             9974
# 12                             9273
# 13                             9277
# 14                             9922
# 15                            10156
# 16                            10042
# 17                            10194
# 18                             9296
# 2                              9642
# 3                              9739
# 4                              9435
# 5                              9328
# 6                              9924
# 7   Total Suppliers Not Imported999
#
#                                              Supplier  \
# 2   1 Retail Investments\rSales Team In Southern\r...
# 3                             1131 Thurow-\rCMP_52251
# 4                     1228 Harding Avenue-\rCMP_43179
# 5                  1304 S Roxbury Drive\rLLC-ab:91422
# 6                   14929 Lone Butte Road-\rCMP_50714
# 7                   1507 Watson Boulevard-\rCMP_54905
# 8   1561-81 Kennedy Blvd.\r& 265 Gates Avenue-\rCM...
# 9                                      2121-CMP_52224
# 10                 2257 Akr Wadsworth\rRoad-CMP_55028
# 11                     226 Wyckoff Avenue-\rCMP_42047
# 12                    2347 Canton Highway-\rCMP_54902
# 13  2nd Avenue & 1st Street\rService Station-\rCMP...
# 14             300 & 500 East Truxton\rAve.-CMP_47839
# 15    3000 Houston Street\rDevelopment LLC-\rab:95653
# 2         33rd Street West Service\rStation-CMP_54322
# 3                                      3611-CMP_52246
# 4                       399 Route 22 West-\rCMP_43969
# 5                     405 National Avenue-\rCMP_47849
# 6                      532 South Broadway-\rCMP_51053
# 7               5355-75 South Third\rStreet-CMP_51122
# 8                  5725 Kearny Villa Road-\rCMP_47863
# 9               6380 East 30th Street\rSite-CMP_45601
# 10                                657 Union Boulevard
# 11       700 GOLFMORE\rASSOCIATION INC-\rGLT:CMP:4006
# 12            702 Firm LLC dba The\r702 Firm-ab:90406
# 13                       727 Bellevue Way-\rCMP_46814
# 14                               8391 Pecos-CMP_54824
# 15                   893 New Ashford Road-\rCMP_50452
# 16              95 Eastern Parkway\rCompany-ab:103764
# 17                     960 West Henderson-\rCMP_53359
# ..                                                ...
# 11    White And Lavendar\rPest Contro-\rASI:CMP:10299
# 12                       Whiteside Construction\rCorp
# 13           Wild Game Innovations\rLlc-ASI:CMP:10318
# 14              Wilfong Food & Gas\rLlc-ASI:CMP:10323
# 15                   Wilkins Township-\rASI:CMP:13833
# 16                     William Sather-\rASI:PER:10346
# 17                                 William Shoemaker-
# 2                                            ab:99368
# 3                      William Wimmer-\rASI:PER:20554
# 4               Williamson Yard\rFacilities-CMP_52708
# 5                     Wilmington Office 775-\rLOC_775
# 6                                    Win-R Insulation
# 7                          Woodside 05N LP-\rab:94353
# 8               World Class Demolition\rCorp-ab:56329
# 9                         Wyoming S&P-\rASI:CMP:10440
# 10               Yardley Office 23344-\rASI:LOC:23344
# 11                      York Risk Services-\rab:97024
# 12                         Yvehfe Valadez-\rPER_20010
# 13                         Yvonne Albanez-\rPER_22706
# 14                                      ZZZSTANISLAUS
# 15                       Zaina Thabet-\rASI:PER:14286
# 16  de maximus\rEnvironmental\rRemediation Fund\rA...
# 17          insured unknown -\r14EP0942-\rMMK:CMP:461
# 18          insured unknown -\r14EP1453-\rMMK:CMP:491
# 2           insured unknown -\r28EP0297-\rMMK:CMP:583
# 3           insured unknown -\r28EP0570-\rMMK:CMP:585
# 4           insured unknown -\r4SG03724-\rMMK:CMP:713
# 5           insured unknown -\rASD03746-\rMMK:CMP:735
# 6           insured unknown -\rGMV00053-\rMMK:CMP:801
# 7                                                 NaN
#
#                   Rejection Reason  \
# 2   The value provided is invalid.
# 3   The value provided is invalid.
# 4   The value provided is invalid.
# 5   The value provided is invalid.
# 6   The value provided is invalid.
# 7   The value provided is invalid.
# 8   The value provided is invalid.
# 9   The value provided is invalid.
# 10  The value provided is invalid.
# 11  The value provided is invalid.
# 12  The value provided is invalid.
# 13  The value provided is invalid.
# 14  The value provided is invalid.
# 15  The value provided is invalid.
# 2   The value provided is invalid.
# 3   The value provided is invalid.
# 4   The value provided is invalid.
# 5   The value provided is invalid.
# 6   The value provided is invalid.
# 7   The value provided is invalid.
# 8   The value provided is invalid.
# 9   The value provided is invalid.
# 10  The value provided is invalid.
# 11  The value provided is invalid.
# 12  The value provided is invalid.
# 13  The value provided is invalid.
# 14  The value provided is invalid.
# 15  The value provided is invalid.
# 16  The value provided is invalid.
# 17  The value provided is invalid.
# ..                             ...
# 11  The value provided is invalid.
# 12  The value provided is invalid.
# 13  The value provided is invalid.
# 14  The value provided is invalid.
# 15  The value provided is invalid.
# 16  The value provided is invalid.
# 17  The value provided is invalid.
# 2                              NaN
# 3   The value provided is invalid.
# 4   The value provided is invalid.
# 5   The value provided is invalid.
# 6   The value provided is invalid.
# 7   The value provided is invalid.
# 8   The value provided is invalid.
# 9   The value provided is invalid.
# 10  The value provided is invalid.
# 11  The value provided is invalid.
# 12  The value provided is invalid.
# 13  The value provided is invalid.
# 14  The value provided is invalid.
# 15  The value provided is invalid.
# 16  The value provided is invalid.
# 17  The value provided is invalid.
# 18  The value provided is invalid.
# 2   The value provided is invalid.
# 3   The value provided is invalid.
# 4   The value provided is invalid.
# 5   The value provided is invalid.
# 6   The value provided is invalid.
# 7                              NaN
#
#                                                 Value
# 2   1 Retail Investments Sales\rTeam In Southern C...
# 3                               1131 Thurow-CMP_52251
# 4                     1228 Harding Avenue-\rCMP_43179
# 5                 1304 S Roxbury Drive LLC-\rab:91422
# 6                   14929 Lone Butte Road-\rCMP_50714
# 7                   1507 Watson Boulevard-\rCMP_54905
# 8   1561-81 Kennedy Blvd. & 265\rGates Avenue-CMP_...
# 9                                      2121-CMP_52224
# 10                2257 Akr Wadsworth Road-\rCMP_55028
# 11                     226 Wyckoff Avenue-\rCMP_42047
# 12                    2347 Canton Highway-\rCMP_54902
# 13  2nd Avenue & 1st Street\rService Station-CMP_5...
# 14            300 & 500 East Truxton Ave.-\rCMP_47839
# 15      3000 Houston Street\rDevelopment LLC-ab:95653
# 2         33rd Street West Service\rStation-CMP_54322
# 3                                      3611-CMP_52246
# 4                       399 Route 22 West-\rCMP_43969
# 5                     405 National Avenue-\rCMP_47849
# 6                      532 South Broadway-\rCMP_51053
# 7              5355-75 South Third Street-\rCMP_51122
# 8                  5725 Kearny Villa Road-\rCMP_47863
# 9              6380 East 30th Street Site-\rCMP_45601
# 10                               New Jersey-CMP_47228
# 11       700 GOLFMORE\rASSOCIATION INC-\rGLT:CMP:4006
# 12            702 Firm LLC dba The 702\rFirm-ab:90406
# 13                       727 Bellevue Way-\rCMP_46814
# 14                               8391 Pecos-CMP_54824
# 15                   893 New Ashford Road-\rCMP_50452
# 16             95 Eastern Parkway Company-\rab:103764
# 17                     960 West Henderson-\rCMP_53359
# ..                                                ...
# 11      White And Lavendar Pest\rContro-ASI:CMP:10299
# 12                                  Inc-ASI:CMP:10307
# 13          Wild Game Innovations Llc-\rASI:CMP:10318
# 14             Wilfong Food & Gas Llc-\rASI:CMP:10323
# 15                   Wilkins Township-\rASI:CMP:13833
# 16                     William Sather-\rASI:PER:10346
# 17                         William Shoemaker-ab:99368
# 2                                                 NaN
# 3                      William Wimmer-\rASI:PER:20554
# 4              Williamson Yard Facilities-\rCMP_52708
# 5                     Wilmington Office 775-\rLOC_775
# 6                                    Win-R Insulation
# 7                            Woodside 05N LP-ab:94353
# 8              World Class Demolition Corp-\rab:56329
# 9                         Wyoming S&P-\rASI:CMP:10440
# 10               Yardley Office 23344-\rASI:LOC:23344
# 11                        York Risk Services-ab:97024
# 12                           Yvehfe Valadez-PER_20010
# 13                           Yvonne Albanez-PER_22706
# 14                                      ZZZSTANISLAUS
# 15                         Zaina Thabet-ASI:PER:14286
# 16  de maximus Environmental\rRemediation Fund Acc...
# 17           insured unknown - 14EP0942-\rMMK:CMP:461
# 18           insured unknown - 14EP1453-\rMMK:CMP:491
# 2            insured unknown - 28EP0297-\rMMK:CMP:583
# 3            insured unknown - 28EP0570-\rMMK:CMP:585
# 4            insured unknown - 4SG03724-\rMMK:CMP:713
# 5             insured unknown -\rASD03746-MMK:CMP:735
# 6             insured unknown -\rGMV00053-MMK:CMP:801
# 7                                                 NaN
#
# [1029 rows x 4 columns]
