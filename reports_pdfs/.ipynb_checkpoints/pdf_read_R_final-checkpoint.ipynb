# %%
# Import packages

library(rJava)
library(tabulizer)
library(tabulizerjars)
library(tidyverse)
# Out:
# -- Attaching packages --------------------------------------- tidyverse 1.2.1 --
# v ggplot2 3.2.1     v purrr   0.3.2
# v tibble  2.1.3     v dplyr   0.8.3
# v tidyr   0.8.3     v stringr 1.4.0
# v readr   1.3.1     v forcats 0.4.0
# -- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()

# %%
pdf_contents <- extract_tables("Report_1600821.pdf")

# %%
pdf_content  <- pdf_contents[-1] ## drop 1 st page
pdf_content <- pdf_content[-length(pdf_content)] ## drop last page

# %%
new_pdf_content = list()
new_pdf_content = data.frame()
for (i in pdf_content) {
    page_df <- i %>% data.frame
    page_df <- page_df[-c(1,2),]
    drops <- c("X1","X2","X4","X6")
    page_df <- page_df[ , !(names(page_df) %in% drops)]
    new_pdf_content <- rbind(new_pdf_content,page_df)
}

# %%
colnames(new_pdf_content) <- c("Supplier", "Rejection Reason" , "Value")
#new_pdf_content
# Out:
#      Supplier
# 3    1 Retail Investments\rSales Team In Southern\rCalifornia Inc-\rASI:CMP:9476
# 4    1131 Thurow-\rCMP_52251
# 5    1228 Harding Avenue-\rCMP_43179
# 6    1304 S Roxbury Drive\rLLC-ab:91422
# 7    14929 Lone Butte Road-\rCMP_50714
# 8    1507 Watson Boulevard-\rCMP_54905
# 9    1561-81 Kennedy Blvd.\r& 265 Gates Avenue-\rCMP_50626
# 10   2121-CMP_52224
# 11   2257 Akr Wadsworth\rRoad-CMP_55028
# 12   226 Wyckoff Avenue-\rCMP_42047
# 13   2347 Canton Highway-\rCMP_54902
# 14   2nd Avenue & 1st Street\rService Station-\rCMP_53819
# 15   300 & 500 East Truxton\rAve.-CMP_47839
# 16   3000 Houston Street\rDevelopment LLC-\rab:95653
# 31   33rd Street West Service\rStation-CMP_54322
# 41   3611-CMP_52246
# 51   399 Route 22 West-\rCMP_43969
# 61   405 National Avenue-\rCMP_47849
# 71   532 South Broadway-\rCMP_51053
# 81   5355-75 South Third\rStreet-CMP_51122
# 91   5725 Kearny Villa Road-\rCMP_47863
# 101  6380 East 30th Street\rSite-CMP_45601
# 111  657 Union Boulevard
# 121  700 GOLFMORE\rASSOCIATION INC-\rGLT:CMP:4006
# 131  702 Firm LLC dba The\r702 Firm-ab:90406
# 141  727 Bellevue Way-\rCMP_46814
# 151  8391 Pecos-CMP_54824
# 161  893 New Ashford Road-\rCMP_50452
# 17   95 Eastern Parkway\rCompany-ab:103764
# 18   960 West Henderson-\rCMP_53359
# ...  ...
# 1257 White And Lavendar\rPest Contro-\rASI:CMP:10299
# 1357 Whiteside Construction\rCorp
# 1457 Wild Game Innovations\rLlc-ASI:CMP:10318
# 1557 Wilfong Food & Gas\rLlc-ASI:CMP:10323
# 1657 Wilkins Township-\rASI:CMP:13833
# 1756 William Sather-\rASI:PER:10346
# 1851 William Shoemaker-
# 358  ab:99368
# 458  William Wimmer-\rASI:PER:20554
# 558  Williamson Yard\rFacilities-CMP_52708
# 658  Wilmington Office 775-\rLOC_775
# 758  Win-R Insulation
# 858  Woodside 05N LP-\rab:94353
# 958  World Class Demolition\rCorp-ab:56329
# 1058 Wyoming S&P-\rASI:CMP:10440
# 1158 Yardley Office 23344-\rASI:LOC:23344
# 1258 York Risk Services-\rab:97024
# 1358 Yvehfe Valadez-\rPER_20010
# 1458 Yvonne Albanez-\rPER_22706
# 1558 ZZZSTANISLAUS
# 1658 Zaina Thabet-\rASI:PER:14286
# 1757 de maximus\rEnvironmental\rRemediation Fund\rAccount-ab:57824
# 1852 insured unknown -\r14EP0942-\rMMK:CMP:461
# 1941 insured unknown -\r14EP1453-\rMMK:CMP:491
# 359  insured unknown -\r28EP0297-\rMMK:CMP:583
# 459  insured unknown -\r28EP0570-\rMMK:CMP:585
# 559  insured unknown -\r4SG03724-\rMMK:CMP:713
# 659  insured unknown -\rASD03746-\rMMK:CMP:735
# 759  insured unknown -\rGMV00053-\rMMK:CMP:801
# 859
#      Rejection Reason
# 3    The value provided is invalid.
# 4    The value provided is invalid.
# 5    The value provided is invalid.
# 6    The value provided is invalid.
# 7    The value provided is invalid.
# 8    The value provided is invalid.
# 9    The value provided is invalid.
# 10   The value provided is invalid.
# 11   The value provided is invalid.
# 12   The value provided is invalid.
# 13   The value provided is invalid.
# 14   The value provided is invalid.
# 15   The value provided is invalid.
# 16   The value provided is invalid.
# 31   The value provided is invalid.
# 41   The value provided is invalid.
# 51   The value provided is invalid.
# 61   The value provided is invalid.
# 71   The value provided is invalid.
# 81   The value provided is invalid.
# 91   The value provided is invalid.
# 101  The value provided is invalid.
# 111  The value provided is invalid.
# 121  The value provided is invalid.
# 131  The value provided is invalid.
# 141  The value provided is invalid.
# 151  The value provided is invalid.
# 161  The value provided is invalid.
# 17   The value provided is invalid.
# 18   The value provided is invalid.
# ...  ...
# 1257 The value provided is invalid.
# 1357 The value provided is invalid.
# 1457 The value provided is invalid.
# 1557 The value provided is invalid.
# 1657 The value provided is invalid.
# 1756 The value provided is invalid.
# 1851 The value provided is invalid.
# 358
# 458  The value provided is invalid.
# 558  The value provided is invalid.
# 658  The value provided is invalid.
# 758  The value provided is invalid.
# 858  The value provided is invalid.
# 958  The value provided is invalid.
# 1058 The value provided is invalid.
# 1158 The value provided is invalid.
# 1258 The value provided is invalid.
# 1358 The value provided is invalid.
# 1458 The value provided is invalid.
# 1558 The value provided is invalid.
# 1658 The value provided is invalid.
# 1757 The value provided is invalid.
# 1852 The value provided is invalid.
# 1941 The value provided is invalid.
# 359  The value provided is invalid.
# 459  The value provided is invalid.
# 559  The value provided is invalid.
# 659  The value provided is invalid.
# 759  The value provided is invalid.
# 859
#      Value
# 3    1 Retail Investments Sales\rTeam In Southern California\rInc-ASI:CMP:9476
# 4    1131 Thurow-CMP_52251
# 5    1228 Harding Avenue-\rCMP_43179
# 6    1304 S Roxbury Drive LLC-\rab:91422
# 7    14929 Lone Butte Road-\rCMP_50714
# 8    1507 Watson Boulevard-\rCMP_54905
# 9    1561-81 Kennedy Blvd. & 265\rGates Avenue-CMP_50626
# 10   2121-CMP_52224
# 11   2257 Akr Wadsworth Road-\rCMP_55028
# 12   226 Wyckoff Avenue-\rCMP_42047
# 13   2347 Canton Highway-\rCMP_54902
# 14   2nd Avenue & 1st Street\rService Station-CMP_53819
# 15   300 & 500 East Truxton Ave.-\rCMP_47839
# 16   3000 Houston Street\rDevelopment LLC-ab:95653
# 31   33rd Street West Service\rStation-CMP_54322
# 41   3611-CMP_52246
# 51   399 Route 22 West-\rCMP_43969
# 61   405 National Avenue-\rCMP_47849
# 71   532 South Broadway-\rCMP_51053
# 81   5355-75 South Third Street-\rCMP_51122
# 91   5725 Kearny Villa Road-\rCMP_47863
# 101  6380 East 30th Street Site-\rCMP_45601
# 111  New Jersey-CMP_47228
# 121  700 GOLFMORE\rASSOCIATION INC-\rGLT:CMP:4006
# 131  702 Firm LLC dba The 702\rFirm-ab:90406
# 141  727 Bellevue Way-\rCMP_46814
# 151  8391 Pecos-CMP_54824
# 161  893 New Ashford Road-\rCMP_50452
# 17   95 Eastern Parkway Company-\rab:103764
# 18   960 West Henderson-\rCMP_53359
# ...  ...
# 1257 White And Lavendar Pest\rContro-ASI:CMP:10299
# 1357 Inc-ASI:CMP:10307
# 1457 Wild Game Innovations Llc-\rASI:CMP:10318
# 1557 Wilfong Food & Gas Llc-\rASI:CMP:10323
# 1657 Wilkins Township-\rASI:CMP:13833
# 1756 William Sather-\rASI:PER:10346
# 1851 William Shoemaker-ab:99368
# 358
# 458  William Wimmer-\rASI:PER:20554
# 558  Williamson Yard Facilities-\rCMP_52708
# 658  Wilmington Office 775-\rLOC_775
# 758  Win-R Insulation
# 858  Woodside 05N LP-ab:94353
# 958  World Class Demolition Corp-\rab:56329
# 1058 Wyoming S&P-\rASI:CMP:10440
# 1158 Yardley Office 23344-\rASI:LOC:23344
# 1258 York Risk Services-ab:97024
# 1358 Yvehfe Valadez-PER_20010
# 1458 Yvonne Albanez-PER_22706
# 1558 ZZZSTANISLAUS
# 1658 Zaina Thabet-ASI:PER:14286
# 1757 de maximus Environmental\rRemediation Fund Account-\rab:57824
# 1852 insured unknown - 14EP0942-\rMMK:CMP:461
# 1941 insured unknown - 14EP1453-\rMMK:CMP:491
# 359  insured unknown - 28EP0297-\rMMK:CMP:583
# 459  insured unknown - 28EP0570-\rMMK:CMP:585
# 559  insured unknown - 4SG03724-\rMMK:CMP:713
# 659  insured unknown -\rASD03746-MMK:CMP:735
# 759  insured unknown -\rGMV00053-MMK:CMP:801
# 859

# %%
write.csv(new_pdf_content,'Report_1600821.csv')
