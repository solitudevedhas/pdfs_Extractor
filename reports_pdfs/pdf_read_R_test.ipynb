# %%
library(rJava)
library(tabulizer)
library(tabulizerjars)
library(tidyverse)
# Out:
# -- Attaching packages --------------------------------------- tidyverse 1.2.1 --
# v ggplot2 3.2.1     v purrr   0.3.2
# v tibble  2.1.3     v dplyr   0.8.3
# v tidyr   0.8.3     v stringr 1.4.0
# v readr   1.3.1     v forcats 0.4.0
# -- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()

# %%
pdf_contents <- extract_tables("Report_1600821.pdf")

# %%
pdf_content  <- pdf_contents[-1] ## drop 1 st page
pdf_content <- pdf_content[-length(pdf_content)] ## drop last page
length(pdf_content)
# Out:
# [1] 60

# %%
pdf_content
# Out:
# [[1]]
#       [,1]                     [,2]
#  [1,] "Suppliers Not Imported" ""
#  [2,] "Interface ID"           "Import Action"
#  [3,] "9936"                   "UPDATE"
#  [4,] "9848"                   "UPDATE"
#  [5,] "9628"                   "UPDATE"
#  [6,] "9891"                   "UPDATE"
#  [7,] "9618"                   "UPDATE"
#  [8,] "9763"                   "UPDATE"
#  [9,] "9640"                   "UPDATE"
# [10,] "9528"                   "UPDATE"
# [11,] "9938"                   "UPDATE"
# [12,] "9345"                   "UPDATE"
# [13,] "9748"                   "UPDATE"
# [14,] "10071"                  "UPDATE"
# [15,] "9578"                   "UPDATE"
# [16,] "10107"                  "UPDATE"
#       [,3]
#  [1,] ""
#  [2,] "Supplier"
#  [3,] "1 Retail Investments\rSales Team In Southern\rCalifornia Inc-\rASI:CMP:9476"
#  [4,] "1131 Thurow-\rCMP_52251"
#  [5,] "1228 Harding Avenue-\rCMP_43179"
#  [6,] "1304 S Roxbury Drive\rLLC-ab:91422"
#  [7,] "14929 Lone Butte Road-\rCMP_50714"
#  [8,] "1507 Watson Boulevard-\rCMP_54905"
#  [9,] "1561-81 Kennedy Blvd.\r& 265 Gates Avenue-\rCMP_50626"
# [10,] "2121-CMP_52224"
# [11,] "2257 Akr Wadsworth\rRoad-CMP_55028"
# [12,] "226 Wyckoff Avenue-\rCMP_42047"
# [13,] "2347 Canton Highway-\rCMP_54902"
# [14,] "2nd Avenue & 1st Street\rService Station-\rCMP_53819"
# [15,] "300 & 500 East Truxton\rAve.-CMP_47839"
# [16,] "3000 Houston Street\rDevelopment LLC-\rab:95653"
#       [,4]              [,5]                             [,6]
#  [1,] ""                ""                               ""
#  [2,] "Supplier Number" "Rejection Reason"               "Attribute"
#  [3,] ""                "The value provided is invalid." "VENDOR_NAME"
#  [4,] ""                "The value provided is invalid." "VENDOR_NAME"
#  [5,] ""                "The value provided is invalid." "VENDOR_NAME"
#  [6,] ""                "The value provided is invalid." "VENDOR_NAME"
#  [7,] ""                "The value provided is invalid." "VENDOR_NAME"
#  [8,] ""                "The value provided is invalid." "VENDOR_NAME"
#  [9,] ""                "The value provided is invalid." "VENDOR_NAME"
# [10,] ""                "The value provided is invalid." "VENDOR_NAME"
# [11,] ""                "The value provided is invalid." "VENDOR_NAME"
# [12,] ""                "The value provided is invalid." "VENDOR_NAME"
# [13,] ""                "The value provided is invalid." "VENDOR_NAME"
# [14,] ""                "The value provided is invalid." "VENDOR_NAME"
# [15,] ""                "The value provided is invalid." "VENDOR_NAME"
# [16,] ""                "The value provided is invalid." "VENDOR_NAME"
#       [,7]
#  [1,] ""
#  [2,] "Value"
#  [3,] "1 Retail Investments Sales\rTeam In Southern California\rInc-ASI:CMP:9476"
#  [4,] "1131 Thurow-CMP_52251"
#  [5,] "1228 Harding Avenue-\rCMP_43179"
#  [6,] "1304 S Roxbury Drive LLC-\rab:91422"
#  [7,] "14929 Lone Butte Road-\rCMP_50714"
#  [8,] "1507 Watson Boulevard-\rCMP_54905"
#  [9,] "1561-81 Kennedy Blvd. & 265\rGates Avenue-CMP_50626"
# [10,] "2121-CMP_52224"
# [11,] "2257 Akr Wadsworth Road-\rCMP_55028"
# [12,] "226 Wyckoff Avenue-\rCMP_42047"
# [13,] "2347 Canton Highway-\rCMP_54902"
# [14,] "2nd Avenue & 1st Street\rService Station-CMP_53819"
# [15,] "300 & 500 East Truxton Ave.-\rCMP_47839"
# [16,] "3000 Houston Street\rDevelopment LLC-ab:95653"
#
# [[2]]
#       [,1]                     [,2]
#  [1,] "Suppliers Not Imported" ""
#  [2,] "Interface ID"           "Import Action"
#  [3,] "12227"                  "UPDATE"
#  [4,] "10030"                  "UPDATE"
#  [5,] "9772"                   "UPDATE"
#  [6,] "9812"                   "UPDATE"
#  [7,] "10148"                  "UPDATE"
#  [8,] "9592"                   "UPDATE"
#  [9,] "9977"                   "UPDATE"
# [10,] "9493"                   "UPDATE"
# [11,] "9426"                   "UPDATE"
# [12,] "9973"                   "UPDATE"
# [13,] "9702"                   "UPDATE"
# [14,] "9497"                   "UPDATE"
# [15,] "9717"                   "UPDATE"
# [16,] "9430"                   "UPDATE"
# [17,] "9985"                   "UPDATE"
# [18,] "9390"                   "UPDATE"
# [19,] "9433"                   "UPDATE"
# [20,] "9454"                   "UPDATE"
#       [,3]
#  [1,] ""
#  [2,] "Supplier"
#  [3,] "33rd Street West Service\rStation-CMP_54322"
#  [4,] "3611-CMP_52246"
#  [5,] "399 Route 22 West-\rCMP_43969"
#  [6,] "405 National Avenue-\rCMP_47849"
#  [7,] "532 South Broadway-\rCMP_51053"
#  [8,] "5355-75 South Third\rStreet-CMP_51122"
#  [9,] "5725 Kearny Villa Road-\rCMP_47863"
# [10,] "6380 East 30th Street\rSite-CMP_45601"
# [11,] "657 Union Boulevard"
# [12,] "700 GOLFMORE\rASSOCIATION INC-\rGLT:CMP:4006"
# [13,] "702 Firm LLC dba The\r702 Firm-ab:90406"
# [14,] "727 Bellevue Way-\rCMP_46814"
# [15,] "8391 Pecos-CMP_54824"
# [16,] "893 New Ashford Road-\rCMP_50452"
# [17,] "95 Eastern Parkway\rCompany-ab:103764"
# [18,] "960 West Henderson-\rCMP_53359"
# [19,] "A & B Therapy Inc Dba\rMassage Envy-Redwood\rCity-ASI:CMP:10769"
# [20,] "A&B PROPERTIES"
#       [,4]                     [,5]                             [,6]
#  [1,] ""                       ""                               ""
#  [2,] "Supplier Number"        "Rejection Reason"               "Attribute"
#  [3,] ""                       "The value provided is invalid." "VENDOR_NAME"
#  [4,] ""                       "The value provided is invalid." "VENDOR_NAME"
#  [5,] ""                       "The value provided is invalid." "VENDOR_NAME"
#  [6,] ""                       "The value provided is invalid." "VENDOR_NAME"
#  [7,] ""                       "The value provided is invalid." "VENDOR_NAME"
#  [8,] ""                       "The value provided is invalid." "VENDOR_NAME"
#  [9,] ""                       "The value provided is invalid." "VENDOR_NAME"
# [10,] ""                       "The value provided is invalid." "VENDOR_NAME"
# [11,] "New Jersey-\rCMP_47228" "The value provided is invalid." "SEGMENT1"
# [12,] ""                       "The value provided is invalid." "VENDOR_NAME"
# [13,] ""                       "The value provided is invalid." "VENDOR_NAME"
# [14,] ""                       "The value provided is invalid." "VENDOR_NAME"
# [15,] ""                       "The value provided is invalid." "VENDOR_NAME"
# [16,] ""                       "The value provided is invalid." "VENDOR_NAME"
# [17,] ""                       "The value provided is invalid." "VENDOR_NAME"
# [18,] ""                       "The value provided is invalid." "VENDOR_NAME"
# [19,] ""                       "The value provided is invalid." "VENDOR_NAME"
# [20,] ""                       "The value provided is invalid." "VENDOR_NAME"
#       [,7]
#  [1,] ""
#  [2,] "Value"
#  [3,] "33rd Street West Service\rStation-CMP_54322"
#  [4,] "3611-CMP_52246"
#  [5,] "399 Route 22 West-\rCMP_43969"
#  [6,] "405 National Avenue-\rCMP_47849"
#  [7,] "532 South Broadway-\rCMP_51053"
#  [8,] "5355-75 South Third Street-\rCMP_51122"
#  [9,] "5725 Kearny Villa Road-\rCMP_47863"
# [10,] "6380 East 30th Street Site-\rCMP_45601"
# [11,] "New Jersey-CMP_47228"
# [12,] "700 GOLFMORE\rASSOCIATION INC-\rGLT:CMP:4006"
# [13,] "702 Firm LLC dba The 702\rFirm-ab:90406"
# [14,] "727 Bellevue Way-\rCMP_46814"
# [15,] "8391 Pecos-CMP_54824"
# [16,] "893 New Ashford Road-\rCMP_50452"
# [17,] "95 Eastern Parkway Company-\rab:103764"
# [18,] "960 West Henderson-\rCMP_53359"
# [19,] "A & B Therapy Inc Dba\rMassage Envy-Redwood City-\rASI:CMP:10769"
# [20,] "A&B PROPERTIES INC-"
#
# [[3]]
#       [,1]                     [,2]
#  [1,] "Suppliers Not Imported" ""
#  [2,] "Interface ID"           "Import Action"
#  [3,] ""                       ""
#  [4,] "9374"                   "UPDATE"
#  [5,] "9626"                   "UPDATE"
#  [6,] "9797"                   "UPDATE"
#  [7,] "10140"                  "UPDATE"
#  [8,] "10144"                  "UPDATE"
#  [9,] "10080"                  "UPDATE"
# [10,] "9488"                   "UPDATE"
# [11,] "10184"                  "UPDATE"
# [12,] "10005"                  "UPDATE"
# [13,] "9643"                   "UPDATE"
# [14,] "9901"                   "UPDATE"
# [15,] "9526"                   "UPDATE"
# [16,] "9720"                   "UPDATE"
# [17,] "9389"                   "UPDATE"
# [18,] "9556"                   "UPDATE"
#       [,3]                                                [,4]
#  [1,] ""                                                  ""
#  [2,] "Supplier"                                          "Supplier Number"
#  [3,] "INC-CMP_24066"                                     ""
#  [4,] "ADDINGTON\rRESOUR-CMP_24153"                       ""
#  [5,] "AFFILIATED\rENGINEERING\rLABORATORIES-\rCMP_14556" ""
#  [6,] "ALLSTATE BUILDING\rLP-CMP_24322"                   ""
#  [7,] "AMTRAK-CMP_24435"                                  ""
#  [8,] "AQUEOS\rCORPORATION-\rCMP_24513"                   ""
#  [9,] "ARCHDIOCESE OF\rMILWAUKEE-\rCMP_24524"             ""
# [10,] "ASAP Surveillance-\rASI:CMP:23781"                 ""
# [11,] "AT&T 67526-\rLOC_67526"                            ""
# [12,] "ATTORNEY\rMICHAEL B.\rSMITHERS-\rMLE:CMP:10297"    ""
# [13,] "AVAYA INC-\rCMP_24637"                             ""
# [14,] "Acck Insurance Services\rInc-ASI:CMP:10805"        ""
# [15,] "AccuTran Inc-ab:90540"                             ""
# [16,] "Actuarial Careers Inc-\rCMP_63373"                 ""
# [17,] "Albion MGP-\rCMP_41969"                            ""
# [18,] "Albuquerque Office\r21269-ASI:LOC:21269"           ""
#       [,5]                             [,6]
#  [1,] ""                               ""
#  [2,] "Rejection Reason"               "Attribute"
#  [3,] ""                               ""
#  [4,] "The value provided is invalid." "VENDOR_NAME"
#  [5,] "The value provided is invalid." "VENDOR_NAME"
#  [6,] "The value provided is invalid." "VENDOR_NAME"
#  [7,] "The value provided is invalid." "VENDOR_NAME"
#  [8,] "The value provided is invalid." "VENDOR_NAME"
#  [9,] "The value provided is invalid." "VENDOR_NAME"
# [10,] "The value provided is invalid." "VENDOR_NAME"
# [11,] "The value provided is invalid." "VENDOR_NAME"
# [12,] "The value provided is invalid." "VENDOR_NAME"
# [13,] "The value provided is invalid." "VENDOR_NAME"
# [14,] "The value provided is invalid." "VENDOR_NAME"
# [15,] "The value provided is invalid." "VENDOR_NAME"
# [16,] "The value provided is invalid." "VENDOR_NAME"
# [17,] "The value provided is invalid." "VENDOR_NAME"
# [18,] "The value provided is invalid." "VENDOR_NAME"
#       [,7]
#  [1,] ""
#  [2,] "Value"
#  [3,] "CMP_24066"
#  [4,] "ADDINGTON RESOUR-\rCMP_24153"
#  [5,] "AFFILIATED\rENGINEERING\rLABORATORIES-\rCMP_14556"
#  [6,] "ALLSTATE BUILDING LP-\rCMP_24322"
#  [7,] "AMTRAK-CMP_24435"
#  [8,] "AQUEOS CORPORATION-\rCMP_24513"
#  [9,] "ARCHDIOCESE OF\rMILWAUKEE-CMP_24524"
# [10,] "ASAP Surveillance-\rASI:CMP:23781"
# [11,] "AT&T 67526-LOC_67526"
# [12,] "ATTORNEY MICHAEL B.\rSMITHERS-\rMLE:CMP:10297"
# [13,] "AVAYA INC-CMP_24637"
# [14,] "Acck Insurance Services Inc-\rASI:CMP:10805"
# [15,] "AccuTran Inc-ab:90540"
# [16,] "Actuarial Careers Inc-\rCMP_63373"
# [17,] "Albion MGP-CMP_41969"
# [18,] "Albuquerque Office 21269-\rASI:LOC:21269"
#
# [[4]]
#       [,1]                     [,2]
#  [1,] "Suppliers Not Imported" ""
#  [2,] "Interface ID"           "Import Action"
#  [3,] "9412"                   "UPDATE"
#  [4,] "9353"                   "UPDATE"
#  [5,] "9813"                   "UPDATE"
#  [6,] "9421"                   "UPDATE"
#  [7,] "9960"                   "UPDATE"
#  [8,] "9692"                   "UPDATE"
#  [9,] "9550"                   "UPDATE"
# [10,] "9384"                   "UPDATE"
# [11,] "10158"                  "UPDATE"
# [12,] "9646"                   "UPDATE"
# [13,] "9299"                   "UPDATE"
# [14,] "9614"                   "UPDATE"
# [15,] "10089"                  "UPDATE"
# [16,] "9434"                   "UPDATE"
# [17,] "9543"                   "UPDATE"
#       [,3]
#  [1,] ""
#  [2,] "Supplier"
#  [3,] "Alco"
#  [4,] "Alexander Group LLC-\rab:53775"
#  [5,] "Alexander Ricks PLLC-\rASI:CMP:24517"
#  [6,] "Alexandria Office\r25369-ASI:LOC:25369"
#  [7,] "All American\rWaterproofing Indoor\rEnvironmental\rSpecialist-ASI:CMP:579"
#  [8,] "All Equipment Rental-\rMKL:CMP:7"
#  [9,] "All Southern Termite\rService Inc-\rASI:CMP:616"
# [10,] "Allen K. Brown-\rASI:CMP:20738"
# [11,] "Allied Construction\rServices Ii"
# [12,] "Alma Marquez-\rPER_20022"
# [13,] "Alma Piston North Court\rProperty-CMP_44479"
# [14,] "Alpha To Omega\rTermite & Pest Control\rInc-ASI:CMP:685"
# [15,] "Alpure Environmental\rServices"
# [16,] "AmeriTrust Group Inc\rDBA Meadowbrook\rInsurance Group Inc-\rab:102639"
# [17,] "American Payroll\rAssociation 63087-"
#       [,4]              [,5]                             [,6]
#  [1,] ""                ""                               ""
#  [2,] "Supplier Number" "Rejection Reason"               "Attribute"
#  [3,] ""                "The value provided is invalid." "VENDOR_NAME"
#  [4,] ""                "The value provided is invalid." "VENDOR_NAME"
#  [5,] ""                "The value provided is invalid." "VENDOR_NAME"
#  [6,] ""                "The value provided is invalid." "VENDOR_NAME"
#  [7,] ""                "The value provided is invalid." "VENDOR_NAME"
#  [8,] ""                "The value provided is invalid." "VENDOR_NAME"
#  [9,] ""                "The value provided is invalid." "VENDOR_NAME"
# [10,] ""                "The value provided is invalid." "VENDOR_NAME"
# [11,] ""                "The value provided is invalid." "VENDOR_NAME"
# [12,] ""                "The value provided is invalid." "VENDOR_NAME"
# [13,] ""                "The value provided is invalid." "VENDOR_NAME"
# [14,] ""                "The value provided is invalid." "VENDOR_NAME"
# [15,] ""                "The value provided is invalid." "VENDOR_NAME"
# [16,] ""                "The value provided is invalid." "VENDOR_NAME"
# [17,] ""                "The value provided is invalid." "VENDOR_NAME"
#       [,7]
#  [1,] ""
#  [2,] "Value"
#  [3,] "Alco"
#  [4,] "Alexander Group LLC-\rab:53775"
#  [5,] "Alexander Ricks PLLC-\rASI:CMP:24517"
#  [6,] "Alexandria Office 25369-\rASI:LOC:25369"
#  [7,] "All American Waterproofing\rIndoor Environmental\rSpecialist-ASI:CMP:579"
#  [8,] "All Equipment Rental-\rMKL:CMP:7"
#  [9,] "All Southern Termite Service\rInc-ASI:CMP:616"
# [10,] "Allen K. Brown-\rASI:CMP:20738"
# [11,] "Allied Construction Services Ii"
# [12,] "Alma Marquez-PER_20022"
# [13,] "Alma Piston North Court\rProperty-CMP_44479"
# [14,] "Alpha To Omega Termite &\rPest Control Inc-\rASI:CMP:685"
# [15,] "Alpure Environmental\rServices"
# [16,] "AmeriTrust Group Inc DBA\rMeadowbrook Insurance\rGroup Inc-ab:102639"
# [17,] "American Payroll Association\r63087-LOC_63087"
#
# [[5]]
#       [,1]                     [,2]
#  [1,] "Suppliers Not Imported" ""
#  [2,] "Interface ID"           "Import Action"
#  [3,] ""                       ""
#  [4,] "9575"                   "UPDATE"
#  [5,] "9703"                   "UPDATE"
#  [6,] "9823"                   "UPDATE"
#  [7,] "10188"                  "UPDATE"
#  [8,] "9712"                   "UPDATE"
#  [9,] "9877"                   "UPDATE"
# [10,] "9580"                   "UPDATE"
# [11,] "9381"                   "UPDATE"
# [12,] "9912"                   "UPDATE"
# [13,] "9679"                   "UPDATE"
# [14,] "9604"                   "UPDATE"
# [15,] "12244"                  "UPDATE"
# [16,] "10102"                  "UPDATE"
# [17,] "9525"                   "UPDATE"
# [18,] "9371"                   "UPDATE"
# [19,] "9716"                   "UPDATE"
# [20,] "9311"                   "UPDATE"
# [21,] "9481"                   "UPDATE"
#       [,3]
#  [1,] ""
#  [2,] "Supplier"
#  [3,] "LOC_63087"
#  [4,] "American Red Cross\r67578-LOC_67578"
#  [5,] "Ami-CMP_54695"
#  [6,] "Amoskeag-CMP_43329"
#  [7,] "Anchorage Office\r26604-ASI:LOC:26604"
#  [8,] "Ann Fiore-PER_5130"
#  [9,] "Annette Sergison-\rab:102955"
# [10,] "Aqua-Tech/Mec-\rCMP_42612"
# [11,] "Arata Swingle Sodhi &\rVan Egmond a\rProfessional\rCorporation-ab:85648"
# [12,] "Arc Con Construction\rInc-ASI:CMP:928"
# [13,] "Argianas & Associates\rInc-ASI:CMP:27023"
# [14,] "Arizona Axis Capital\rLlc-ASI:CMP:10955"
# [15,] "Art-ASI:CMP:994"
# [16,] "Asbestos Corporation Of\rAmerica-ASI:CMP:1021"
# [17,] "Ashland Branded #710-\r000 Conneaut-\rCMP_42161"
# [18,] "Aspen Publishers"
# [19,] "Astoria Office 25762-\rASI:LOC:25762"
# [20,] "Astra Thibodeaux\rCertified Court Reporter-\rCMP_15528"
# [21,] "At Commercial Painting-"
#       [,4]              [,5]                             [,6]
#  [1,] ""                ""                               ""
#  [2,] "Supplier Number" "Rejection Reason"               "Attribute"
#  [3,] ""                ""                               ""
#  [4,] ""                "The value provided is invalid." "VENDOR_NAME"
#  [5,] ""                "The value provided is invalid." "VENDOR_NAME"
#  [6,] ""                "The value provided is invalid." "VENDOR_NAME"
#  [7,] ""                "The value provided is invalid." "VENDOR_NAME"
#  [8,] ""                "The value provided is invalid." "VENDOR_NAME"
#  [9,] ""                "The value provided is invalid." "VENDOR_NAME"
# [10,] ""                "The value provided is invalid." "VENDOR_NAME"
# [11,] ""                "The value provided is invalid." "VENDOR_NAME"
# [12,] ""                "The value provided is invalid." "VENDOR_NAME"
# [13,] ""                "The value provided is invalid." "VENDOR_NAME"
# [14,] ""                "The value provided is invalid." "VENDOR_NAME"
# [15,] ""                "The value provided is invalid." "VENDOR_NAME"
# [16,] ""                "The value provided is invalid." "VENDOR_NAME"
# [17,] ""                "The value provided is invalid." "VENDOR_NAME"
# [18,] ""                "The value provided is invalid." "VENDOR_NAME"
# [19,] ""                "The value provided is invalid." "VENDOR_NAME"
# [20,] ""                "The value provided is invalid." "VENDOR_NAME"
# [21,] ""                "The value provided is invalid." "VENDOR_NAME"
#       [,7]
#  [1,] ""
#  [2,] "Value"
#  [3,] ""
#  [4,] "American Red Cross 67578-\rLOC_67578"
#  [5,] "Ami-CMP_54695"
#  [6,] "Amoskeag-CMP_43329"
#  [7,] "Anchorage Office 26604-\rASI:LOC:26604"
#  [8,] "Ann Fiore-PER_5130"
#  [9,] "Annette Sergison-ab:102955"
# [10,] "Aqua-Tech/Mec-CMP_42612"
# [11,] "Arata Swingle Sodhi & Van\rEgmond a Professional\rCorporation-ab:85648"
# [12,] "Arc Con Construction Inc-\rASI:CMP:928"
# [13,] "Argianas & Associates Inc-\rASI:CMP:27023"
# [14,] "Arizona Axis Capital Llc-\rASI:CMP:10955"
# [15,] "Art-ASI:CMP:994"
# [16,] "Asbestos Corporation Of\rAmerica-ASI:CMP:1021"
# [17,] "Ashland Branded #710-000\rConneaut-CMP_42161"
# [18,] "Aspen Publishers"
# [19,] "Astoria Office 25762-\rASI:LOC:25762"
# [20,] "Astra Thibodeaux Certified\rCourt Reporter-CMP_15528"
# [21,] "At Commercial Painting-"
#
# [[6]]
#       [,1]                     [,2]
#  [1,] "Suppliers Not Imported" ""
#  [2,] "Interface ID"           "Import Action"
#  [3,] ""                       ""
#  [4,] "9605"                   "UPDATE"
#  [5,] "10063"                  "UPDATE"
#  [6,] "9704"                   "UPDATE"
#  [7,] "9875"                   "UPDATE"
#  [8,] "10059"                  "UPDATE"
#  [9,] "9290"                   "UPDATE"
# [10,] "9329"                   "UPDATE"
# [11,] "9641"                   "UPDATE"
# [12,] "9530"                   "UPDATE"
# [13,] "10182"                  "UPDATE"
# [14,] "9438"                   "UPDATE"
# [15,] "9939"                   "UPDATE"
# [16,] "9738"                   "UPDATE"
# [17,] "10214"                  "UPDATE"
# [18,] "9919"                   "UPDATE"
# [19,] "9576"                   "UPDATE"
# [20,] "10057"                  "UPDATE"
# [21,] "9986"                   "UPDATE"
#       [,3]                                         [,4]
#  [1,] ""                                           ""
#  [2,] "Supplier"                                   "Supplier Number"
#  [3,] "ASI:CMP:1052"                               ""
#  [4,] "Atlanta Office 22838-\rASI:LOC:22838"       ""
#  [5,] "Atlanta Office 25617-\rASI:LOC:25617"       ""
#  [6,] "Atlantic Lead\rConsultants"                 ""
#  [7,] "Atlas Services Group\rUsa Inc-ASI:CMP:1087" ""
#  [8,] "Aurora-CMP_45846"                           ""
#  [9,] "Austin Office 22803-\rASI:LOC:22803"        ""
# [10,] "Austin Office 23292-\rASI:LOC:23292"        ""
# [11,] "Austin Office 25867-\rASI:LOC:25867"        ""
# [12,] "Auto Owners Insurance\rCompany-ab:96903"    ""
# [13,] "AvalonBay\rCommunities Inc-\rab:56293"      ""
# [14,] "Avanti-CMP_53092"                           ""
# [15,] "Avtex Fibers Inc.-\rCMP_41934"              ""
# [16,] "Axis Construction\rConsulting"              ""
# [17,] "Azure Advisors Inc-\rab:54317"              ""
# [18,] "B/Fert 0466"                                ""
# [19,] "BAY AREA\rREPORTING"                        ""
# [20,] "BEHLER YOUNG\rCOMPANY-\rCMP_24793"          ""
# [21,] "BELLEVUE Office"                            ""
#       [,5]                             [,6]
#  [1,] ""                               ""
#  [2,] "Rejection Reason"               "Attribute"
#  [3,] ""                               ""
#  [4,] "The value provided is invalid." "VENDOR_NAME"
#  [5,] "The value provided is invalid." "VENDOR_NAME"
#  [6,] "The value provided is invalid." "VENDOR_NAME"
#  [7,] "The value provided is invalid." "VENDOR_NAME"
#  [8,] "The value provided is invalid." "VENDOR_NAME"
#  [9,] "The value provided is invalid." "VENDOR_NAME"
# [10,] "The value provided is invalid." "VENDOR_NAME"
# [11,] "The value provided is invalid." "VENDOR_NAME"
# [12,] "The value provided is invalid." "VENDOR_NAME"
# [13,] "The value provided is invalid." "VENDOR_NAME"
# [14,] "The value provided is invalid." "VENDOR_NAME"
# [15,] "The value provided is invalid." "VENDOR_NAME"
# [16,] "The value provided is invalid." "VENDOR_NAME"
# [17,] "The value provided is invalid." "VENDOR_NAME"
# [18,] "The value provided is invalid." "VENDOR_NAME"
# [19,] "The value provided is invalid." "VENDOR_NAME"
# [20,] "The value provided is invalid." "VENDOR_NAME"
# [21,] "The value provided is invalid." "VENDOR_NAME"
#       [,7]
#  [1,] ""
#  [2,] "Value"
#  [3,] "ASI:CMP:1052"
#  [4,] "Atlanta Office 22838-\rASI:LOC:22838"
#  [5,] "Atlanta Office 25617-\rASI:LOC:25617"
#  [6,] "Atlantic Lead Consultants"
#  [7,] "Atlas Services Group Usa Inc-\rASI:CMP:1087"
#  [8,] "Aurora-CMP_45846"
#  [9,] "Austin Office 22803-\rASI:LOC:22803"
# [10,] "Austin Office 23292-\rASI:LOC:23292"
# [11,] "Austin Office 25867-\rASI:LOC:25867"
# [12,] "Auto Owners Insurance\rCompany-ab:96903"
# [13,] "AvalonBay Communities Inc-\rab:56293"
# [14,] "Avanti-CMP_53092"
# [15,] "Avtex Fibers Inc.-CMP_41934"
# [16,] "Axis Construction Consulting"
# [17,] "Azure Advisors Inc-ab:54317"
# [18,] "B/Fert 0466"
# [19,] "BAY AREA REPORTING"
# [20,] "BEHLER YOUNG\rCOMPANY-CMP_24793"
# [21,] "BELLEVUE Office 14165-"
#
# [[7]]
#       [,1]                     [,2]
#  [1,] "Suppliers Not Imported" ""
#  [2,] "Interface ID"           "Import Action"
#  [3,] ""                       ""
#  [4,] "10212"                  "UPDATE"
#  [5,] "12245"                  "UPDATE"
#  [6,] "9908"                   "UPDATE"
#  [7,] "9514"                   "UPDATE"
#  [8,] "9360"                   "UPDATE"
#  [9,] "9417"                   "UPDATE"
# [10,] "9405"                   "UPDATE"
# [11,] "9517"                   "UPDATE"
# [12,] "9935"                   "UPDATE"
# [13,] "10092"                  "UPDATE"
# [14,] "9928"                   "UPDATE"
# [15,] "9999"                   "UPDATE"
# [16,] "9344"                   "UPDATE"
# [17,] "9314"                   "UPDATE"
# [18,] "9987"                   "UPDATE"
# [19,] "9894"                   "UPDATE"
#       [,3]                                      [,4]
#  [1,] ""                                        ""
#  [2,] "Supplier"                                "Supplier Number"
#  [3,] "14165-LOC_14165"                         ""
#  [4,] "BELVIEU\rENTERPRISES-\rMMK:CMP:2051"     ""
#  [5,] "BIG POLL & SON\rCONSTRUCT-\rCMP_24872"   ""
#  [6,] "BIG THREE-\rMMK:CMP:2069"                ""
#  [7,] "BLUE NORTHERN\rBUILDERS INC-\rGLT:CMP:5" ""
#  [8,] "BOWATER NORTH\rAMERIC-\rMMK:CMP:2098"    ""
#  [9,] "BRANDT HOMES INC-\rCMP_24997"            ""
# [10,] "BRENNER"                                 ""
# [11,] "BRIAN BOEHLER-\rGLT:PER:30"              ""
# [12,] "BRINKMAN-\rCMP_25036"                    ""
# [13,] "BUDD-\rMMK:CMP:2124"                     ""
# [14,] "BYRON\rENTERPRISES-\rCMP_66659"          ""
# [15,] "BYWATER MARINE-\rCMP_25155"              ""
# [16,] "Babin & Seeger"                          ""
# [17,] "Barbara Haston-\rPER_23020"              ""
# [18,] "Barney & Karamanis\rLLP-ASI:CMP:27008"   ""
# [19,] "Barron"                                  ""
#       [,5]                             [,6]
#  [1,] ""                               ""
#  [2,] "Rejection Reason"               "Attribute"
#  [3,] ""                               ""
#  [4,] "The value provided is invalid." "VENDOR_NAME"
#  [5,] "The value provided is invalid." "VENDOR_NAME"
#  [6,] "The value provided is invalid." "VENDOR_NAME"
#  [7,] "The value provided is invalid." "VENDOR_NAME"
#  [8,] "The value provided is invalid." "VENDOR_NAME"
#  [9,] "The value provided is invalid." "VENDOR_NAME"
# [10,] "The value provided is invalid." "VENDOR_NAME"
# [11,] "The value provided is invalid." "VENDOR_NAME"
# [12,] "The value provided is invalid." "VENDOR_NAME"
# [13,] "The value provided is invalid." "VENDOR_NAME"
# [14,] "The value provided is invalid." "VENDOR_NAME"
# [15,] "The value provided is invalid." "VENDOR_NAME"
# [16,] "The value provided is invalid." "VENDOR_NAME"
# [17,] "The value provided is invalid." "VENDOR_NAME"
# [18,] "The value provided is invalid." "VENDOR_NAME"
# [19,] "The value provided is invalid." "VENDOR_NAME"
#       [,7]
#  [1,] ""
#  [2,] "Value"
#  [3,] "LOC_14165"
#  [4,] "BELVIEU ENTERPRISES-\rMMK:CMP:2051"
#  [5,] "BIG POLL & SON\rCONSTRUCT-CMP_24872"
#  [6,] "BIG THREE-\rMMK:CMP:2069"
#  [7,] "BLUE NORTHERN\rBUILDERS INC-GLT:CMP:5"
#  [8,] "BOWATER NORTH\rAMERIC-MMK:CMP:2098"
#  [9,] "BRANDT HOMES INC-\rCMP_24997"
# [10,] "BRENNER"
# [11,] "BRIAN BOEHLER-\rGLT:PER:30"
# [12,] "BRINKMAN-CMP_25036"
# [13,] "BUDD-MMK:CMP:2124"
# [14,] "BYRON ENTERPRISES-\rCMP_66659"
# [15,] "BYWATER MARINE-\rCMP_25155"
# [16,] "Babin & Seeger"
# [17,] "Barbara Haston-PER_23020"
# [18,] "Barney & Karamanis LLP-\rASI:CMP:27008"
# [19,] "Barron"
#
# [[8]]
#       [,1]                     [,2]
#  [1,] "Suppliers Not Imported" ""
#  [2,] "Interface ID"           "Import Action"
#  [3,] "9680"                   "UPDATE"
#  [4,] "9278"                   "UPDATE"
#  [5,] "9898"                   "UPDATE"
#  [6,] "10195"                  "UPDATE"
#  [7,] "10032"                  "UPDATE"
#  [8,] "9473"                   "UPDATE"
#  [9,] "12258"                  "UPDATE"
# [10,] "10121"                  "UPDATE"
# [11,] "9307"                   "UPDATE"
# [12,] "10135"                  "UPDATE"
# [13,] "10129"                  "UPDATE"
# [14,] "9752"                   "UPDATE"
# [15,] "9457"                   "UPDATE"
# [16,] "9786"                   "UPDATE"
# [17,] "9332"                   "UPDATE"
# [18,] "9322"                   "UPDATE"
# [19,] "9458"                   "UPDATE"
# [20,] "9442"                   "UPDATE"
# [21,] "10024"                  "UPDATE"
#       [,3]                                         [,4]
#  [1,] ""                                           ""
#  [2,] "Supplier"                                   "Supplier Number"
#  [3,] "Bayless Es Pta-\rASI:CMP:1256"              ""
#  [4,] "Beaver Mills-\rCMP_48727"                   ""
#  [5,] "Becker Plating Inc-\rab:55869"              ""
#  [6,] "Bellefonte Office 16775-\rLOC_16775"        ""
#  [7,] "Ben Bonilla-\rASI:CMP:1318"                 ""
#  [8,] "Berryman Products"                          ""
#  [9,] "Bessemer Office 16327-\rLOC_16327"          ""
# [10,] "Bethesda Office 26514-\rASI:LOC:26514"      ""
# [11,] "Beverage Management"                        ""
# [12,] "Beverly Hills Office\r23851-ASI:LOC:23851"  ""
# [13,] "Big D Concrete Inc-\rASI:CMP:11101"         ""
# [14,] "Bill Mateikis-ab:89543"                     ""
# [15,] "Birmingham Office\r23694-ASI:LOC:23694"     ""
# [16,] "Birmingham Office\r3758-LOC_3758"           ""
# [17,] "Birmingham Service\rShop-CMP_51076"         ""
# [18,] "Black"                                      "LLP-\rASI:CMP:20231"
# [19,] "Blackstone Development\rInc-ab:100460"      ""
# [20,] "Blanton Exterminating\rCo Inc-ASI:CMP:1451" ""
# [21,] "Bluebird-CMP_45253"                         ""
#       [,5]                             [,6]
#  [1,] ""                               ""
#  [2,] "Rejection Reason"               "Attribute"
#  [3,] "The value provided is invalid." "VENDOR_NAME"
#  [4,] "The value provided is invalid." "VENDOR_NAME"
#  [5,] "The value provided is invalid." "VENDOR_NAME"
#  [6,] "The value provided is invalid." "VENDOR_NAME"
#  [7,] "The value provided is invalid." "VENDOR_NAME"
#  [8,] "The value provided is invalid." "VENDOR_NAME"
#  [9,] "The value provided is invalid." "VENDOR_NAME"
# [10,] "The value provided is invalid." "VENDOR_NAME"
# [11,] "The value provided is invalid." "VENDOR_NAME"
# [12,] "The value provided is invalid." "VENDOR_NAME"
# [13,] "The value provided is invalid." "VENDOR_NAME"
# [14,] "The value provided is invalid." "VENDOR_NAME"
# [15,] "The value provided is invalid." "VENDOR_NAME"
# [16,] "The value provided is invalid." "VENDOR_NAME"
# [17,] "The value provided is invalid." "VENDOR_NAME"
# [18,] "The value provided is invalid." "SEGMENT1"
# [19,] "The value provided is invalid." "VENDOR_NAME"
# [20,] "The value provided is invalid." "VENDOR_NAME"
# [21,] "The value provided is invalid." "VENDOR_NAME"
#       [,7]
#  [1,] ""
#  [2,] "Value"
#  [3,] "Bayless Es Pta-ASI:CMP:1256"
#  [4,] "Beaver Mills-CMP_48727"
#  [5,] "Becker Plating Inc-ab:55869"
#  [6,] "Bellefonte Office 16775-\rLOC_16775"
#  [7,] "Ben Bonilla-ASI:CMP:1318"
#  [8,] "Berryman Products"
#  [9,] "Bessemer Office 16327-\rLOC_16327"
# [10,] "Bethesda Office 26514-\rASI:LOC:26514"
# [11,] "Beverage Management"
# [12,] "Beverly Hills Office 23851-\rASI:LOC:23851"
# [13,] "Big D Concrete Inc-\rASI:CMP:11101"
# [14,] "Bill Mateikis-ab:89543"
# [15,] "Birmingham Office 23694-\rASI:LOC:23694"
# [16,] "Birmingham Office 3758-\rLOC_3758"
# [17,] "Birmingham Service Shop-\rCMP_51076"
# [18,] "LLP-ASI:CMP:20231"
# [19,] "Blackstone Development Inc-\rab:100460"
# [20,] "Blanton Exterminating Co Inc-\rASI:CMP:1451"
# [21,] "Bluebird-CMP_45253"
#
# [[9]]
#       [,1]                     [,2]
#  [1,] "Suppliers Not Imported" ""
#  [2,] "Interface ID"           "Import Action"
#  [3,] "9338"                   "UPDATE"
#  [4,] "9619"                   "UPDATE"
#  [5,] "9804"                   "UPDATE"
#  [6,] "9515"                   "UPDATE"
#  [7,] "9869"                   "UPDATE"
#  [8,] "10145"                  "UPDATE"
#  [9,] "9483"                   "UPDATE"
# [10,] "9275"                   "UPDATE"
# [11,] "9809"                   "UPDATE"
# [12,] "9700"                   "UPDATE"
# [13,] "9388"                   "UPDATE"
# [14,] "10203"                  "UPDATE"
# [15,] "9790"                   "UPDATE"
# [16,] "10007"                  "UPDATE"
# [17,] "9911"                   "UPDATE"
# [18,] "9293"                   "UPDATE"
# [19,] "9904"                   "UPDATE"
#       [,3]
#  [1,] ""
#  [2,] "Supplier"
#  [3,] "Boston Office 18303-\rLOC_18303"
#  [4,] "Boston Office 66547-\rLOC_66547"
#  [5,] "Boynton Beach Office\r20610-ASI:LOC:20610"
#  [6,] "Boys & Girls Clubs of\rAmerica-ab:97846"
#  [7,] "Br Associates"
#  [8,] "Brandeis School-\rab:89449"
#  [9,] "Bridge Street Service\rStation-CMP_54103"
# [10,] "Bridgefield Employers\rInsurance Co.-\rCMP_25031"
# [11,] "Bridges Domestic &\rSexual Violence Support\rService-CMP_63293"
# [12,] "Brighton Landfill-\rCMP_55774"
# [13,] "Brooklyn Office 25148-\rASI:LOC:25148"
# [14,] "Brown & Brown of\rFlorida"
# [15,] "Buchhammer & Kehl"
# [16,] "Buckingham Browne &\rNichols (account)-\rab:96068"
# [17,] "Buckman-Mitchell"
# [18,] "Buffalo Office 17390-\rLOC_17390"
# [19,] "Bugs Be Gone Inc-\rASI:CMP:1691"
#       [,4]                       [,5]                             [,6]
#  [1,] ""                         ""                               ""
#  [2,] "Supplier Number"          "Rejection Reason"               "Attribute"
#  [3,] ""                         "The value provided is invalid." "VENDOR_NAME"
#  [4,] ""                         "The value provided is invalid." "VENDOR_NAME"
#  [5,] ""                         "The value provided is invalid." "VENDOR_NAME"
#  [6,] ""                         "The value provided is invalid." "VENDOR_NAME"
#  [7,] "Inc. Dba:-\rASI:CMP:1538" "The value provided is invalid." "SEGMENT1"
#  [8,] ""                         "The value provided is invalid." "VENDOR_NAME"
#  [9,] ""                         "The value provided is invalid." "VENDOR_NAME"
# [10,] ""                         "The value provided is invalid." "VENDOR_NAME"
# [11,] ""                         "The value provided is invalid." "VENDOR_NAME"
# [12,] ""                         "The value provided is invalid." "VENDOR_NAME"
# [13,] ""                         "The value provided is invalid." "VENDOR_NAME"
# [14,] ""                         "The value provided is invalid." "VENDOR_NAME"
# [15,] ""                         "The value provided is invalid." "VENDOR_NAME"
# [16,] ""                         "The value provided is invalid." "VENDOR_NAME"
# [17,] ""                         "The value provided is invalid." "VENDOR_NAME"
# [18,] ""                         "The value provided is invalid." "VENDOR_NAME"
# [19,] ""                         "The value provided is invalid." "VENDOR_NAME"
#       [,7]
#  [1,] ""
#  [2,] "Value"
#  [3,] "Boston Office 18303-\rLOC_18303"
#  [4,] "Boston Office 66547-\rLOC_66547"
#  [5,] "Boynton Beach Office 20610-\rASI:LOC:20610"
#  [6,] "Boys & Girls Clubs of\rAmerica-ab:97846"
#  [7,] "Inc. Dba:-ASI:CMP:1538"
#  [8,] "Brandeis School-ab:89449"
#  [9,] "Bridge Street Service Station-\rCMP_54103"
# [10,] "Bridgefield Employers\rInsurance Co.-CMP_25031"
# [11,] "Bridges Domestic & Sexual\rViolence Support Service-\rCMP_63293"
# [12,] "Brighton Landfill-CMP_55774"
# [13,] "Brooklyn Office 25148-\rASI:LOC:25148"
# [14,] "Brown & Brown of Florida"
# [15,] "Buchhammer & Kehl"
# [16,] "Buckingham Browne &\rNichols (account)-ab:96068"
# [17,] "Buckman-Mitchell"
# [18,] "Buffalo Office 17390-\rLOC_17390"
# [19,] "Bugs Be Gone Inc-\rASI:CMP:1691"
#
# [[10]]
#       [,1]                     [,2]
#  [1,] "Suppliers Not Imported" ""
#  [2,] "Interface ID"           "Import Action"
#  [3,] "9934"                   "UPDATE"
#  [4,] "12252"                  "UPDATE"
#  [5,] "9347"                   "UPDATE"
#  [6,] "10068"                  "UPDATE"
#  [7,] "9859"                   "UPDATE"
#  [8,] "9652"                   "UPDATE"
#  [9,] "9629"                   "UPDATE"
# [10,] "9983"                   "UPDATE"
# [11,] "9512"                   "UPDATE"
# [12,] "9654"                   "UPDATE"
# [13,] "9787"                   "UPDATE"
# [14,] "9926"                   "UPDATE"
# [15,] "10075"                  "UPDATE"
# [16,] "9948"                   "UPDATE"
# [17,] "9648"                   "UPDATE"
# [18,] "9343"                   "UPDATE"
#       [,3]
#  [1,] ""
#  [2,] "Supplier"
#  [3,] "Burbank Operable Unit\r2-CMP_50503"
#  [4,] "Bureau Of Mine-otis-\rCMP_52576"
#  [5,] "Butzel Long-\rCMP_16005"
#  [6,] "Buxbaum"
#  [7,] "Byron R & David B\rWescott-PER_19888"
#  [8,] "C & R Battery Co.-\rCMP_50186"
#  [9,] "C BREWER &\rCOMPANY-\rCMP_25166"
# [10,] "C&C WINDOW &\rDOOR CO INC-\rGLT:CMP:1829"
# [11,] "C. Erickson & Sons"
# [12,] "C.H. Wilkinson\rPhysician Network dba\rChristus Medical Group-\rASI:CMP:23680"
# [13,] "CAMPBELL SAND &\rGRAVEL-CMP_25251"
# [14,] "CAN-DO 69448-\rLOC_69448"
# [15,] "CARLYLE ONE DIST-\rCMP_25310"
# [16,] "CHARLES A.\rWEAVER III-\rCMP_17317"
# ...
#  [5,] "Vica Coal Company"
#  [6,] "Vicki Stringham-\rab:89347"
#  [7,] "Volmar Construction-\rab:56310"
#  [8,] "W N SAMARZICH &\rASSO-MMK:CMP:2623"
#  [9,] "WALNUT CREEK\rOffice 14306-\rLOC_14306"
# [10,] "WATKINS MIDCAL\rDRYWALL-\rCMP_32040"
# [11,] "WESTCHESTER CARE\rAT HOME-CMP_32115"
# [12,] "WINDHAM INJURY\rMANAGEMENT\rGROUP INC-ab:57469"
# [13,] "WM Homes LLC-\rab:85915"
# [14,] "Wagner # 2-CMP_52168"
# [15,] "Wargo and Wargo Co."
# [16,] "Warlynn Enterprises Llc\rDba Planet Beach Ca-\rASI:CMP:13788"
# [17,] "Warwick Landfill-\rCMP_49721"
# [18,] "Waste Oil Tank Site-\rCMP_51335"
# [19,] "Water & Wastewater\rLaboratories Inc-\rASI:CMP:10180"
#       [,4]              [,5]                             [,6]
#  [1,] ""                ""                               ""
#  [2,] "Supplier Number" "Rejection Reason"               "Attribute"
#  [3,] ""                "The value provided is invalid." "VENDOR_NAME"
#  [4,] ""                "The value provided is invalid." "VENDOR_NAME"
#  [5,] ""                "The value provided is invalid." "VENDOR_NAME"
#  [6,] ""                "The value provided is invalid." "VENDOR_NAME"
#  [7,] ""                "The value provided is invalid." "VENDOR_NAME"
#  [8,] ""                "The value provided is invalid." "VENDOR_NAME"
#  [9,] ""                "The value provided is invalid." "VENDOR_NAME"
# [10,] ""                "The value provided is invalid." "VENDOR_NAME"
# [11,] ""                "The value provided is invalid." "VENDOR_NAME"
# [12,] ""                "The value provided is invalid." "VENDOR_NAME"
# [13,] ""                "The value provided is invalid." "VENDOR_NAME"
# [14,] ""                "The value provided is invalid." "VENDOR_NAME"
# [15,] ""                "The value provided is invalid." "VENDOR_NAME"
# [16,] ""                "The value provided is invalid." "VENDOR_NAME"
# [17,] ""                "The value provided is invalid." "VENDOR_NAME"
# [18,] ""                "The value provided is invalid." "VENDOR_NAME"
# [19,] ""                "The value provided is invalid." "VENDOR_NAME"
#       [,7]
#  [1,] ""
#  [2,] "Value"
#  [3,] "VOGEL PAINT & WAX CO.-\rCMP_31942"
#  [4,] "Velsoft-CMP_63596"
#  [5,] "Vica Coal Company"
#  [6,] "Vicki Stringham-ab:89347"
#  [7,] "Volmar Construction-\rab:56310"
#  [8,] "W N SAMARZICH & ASSO-\rMMK:CMP:2623"
#  [9,] "WALNUT CREEK Office\r14306-LOC_14306"
# [10,] "WATKINS MIDCAL\rDRYWALL-CMP_32040"
# [11,] "WESTCHESTER CARE AT\rHOME-CMP_32115"
# [12,] "WINDHAM INJURY\rMANAGEMENT GROUP\rINC-ab:57469"
# [13,] "WM Homes LLC-ab:85915"
# [14,] "Wagner # 2-CMP_52168"
# [15,] "Wargo and Wargo Co."
# [16,] "Warlynn Enterprises Llc Dba\rPlanet Beach Ca-\rASI:CMP:13788"
# [17,] "Warwick Landfill-\rCMP_49721"
# [18,] "Waste Oil Tank Site-\rCMP_51335"
# [19,] "Water & Wastewater\rLaboratories Inc-\rASI:CMP:10180"
#
# [[58]]
#       [,1]                     [,2]
#  [1,] "Suppliers Not Imported" ""
#  [2,] "Interface ID"           "Import Action"
#  [3,] "9820"                   "UPDATE"
#  [4,] "9363"                   "UPDATE"
#  [5,] "9920"                   "UPDATE"
#  [6,] "9690"                   "UPDATE"
#  [7,] "9998"                   "UPDATE"
#  [8,] "9484"                   "UPDATE"
#  [9,] "10002"                  "UPDATE"
# [10,] "10142"                  "UPDATE"
# [11,] "9858"                   "UPDATE"
# [12,] "9596"                   "UPDATE"
# [13,] "9863"                   "UPDATE"
# [14,] "9988"                   "UPDATE"
# [15,] "9852"                   "UPDATE"
# [16,] "9664"                   "UPDATE"
# [17,] "9406"                   "UPDATE"
# [18,] "10122"                  "UPDATE"
#       [,3]
#  [1,] ""
#  [2,] "Supplier"
#  [3,] "Watt Thompson &\rHenneman LLP-\rab:61934"
#  [4,] "Weeks Real Estate-\rASI:CMP:13797"
#  [5,] "West Georgia Pest\rControl"
#  [6,] "West Michigan\rAnesthesia PC-ab:98752"
#  [7,] "West Ohio Gas\rCompany MGP - North\rMarket Street-\rCMP_50922"
#  [8,] "West Valley Structural\rCo-ab:89003"
#  [9,] "Westbury Office 20185-\rASI:LOC:20185"
# [10,] "Westmont Office 24410-\rASI:LOC:24410"
# [11,] "Weymouth Re&c Site-\rCMP_46437"
# [12,] "White And Lavendar\rPest Contro-\rASI:CMP:10299"
# [13,] "Whiteside Construction\rCorp"
# [14,] "Wild Game Innovations\rLlc-ASI:CMP:10318"
# [15,] "Wilfong Food & Gas\rLlc-ASI:CMP:10323"
# [16,] "Wilkins Township-\rASI:CMP:13833"
# [17,] "William Sather-\rASI:PER:10346"
# [18,] "William Shoemaker-"
#       [,4]                  [,5]                             [,6]
#  [1,] ""                    ""                               ""
#  [2,] "Supplier Number"     "Rejection Reason"               "Attribute"
#  [3,] ""                    "The value provided is invalid." "VENDOR_NAME"
#  [4,] ""                    "The value provided is invalid." "VENDOR_NAME"
#  [5,] ""                    "The value provided is invalid." "VENDOR_NAME"
#  [6,] ""                    "The value provided is invalid." "VENDOR_NAME"
#  [7,] ""                    "The value provided is invalid." "VENDOR_NAME"
#  [8,] ""                    "The value provided is invalid." "VENDOR_NAME"
#  [9,] ""                    "The value provided is invalid." "VENDOR_NAME"
# [10,] ""                    "The value provided is invalid." "VENDOR_NAME"
# [11,] ""                    "The value provided is invalid." "VENDOR_NAME"
# [12,] ""                    "The value provided is invalid." "VENDOR_NAME"
# [13,] "Inc-\rASI:CMP:10307" "The value provided is invalid." "SEGMENT1"
# [14,] ""                    "The value provided is invalid." "VENDOR_NAME"
# [15,] ""                    "The value provided is invalid." "VENDOR_NAME"
# [16,] ""                    "The value provided is invalid." "VENDOR_NAME"
# [17,] ""                    "The value provided is invalid." "VENDOR_NAME"
# [18,] ""                    "The value provided is invalid." "VENDOR_NAME"
#       [,7]
#  [1,] ""
#  [2,] "Value"
#  [3,] "Watt Thompson & Henneman\rLLP-ab:61934"
#  [4,] "Weeks Real Estate-\rASI:CMP:13797"
#  [5,] "West Georgia Pest Control"
#  [6,] "West Michigan Anesthesia\rPC-ab:98752"
#  [7,] "West Ohio Gas Company\rMGP - North Market Street-\rCMP_50922"
#  [8,] "West Valley Structural Co-\rab:89003"
#  [9,] "Westbury Office 20185-\rASI:LOC:20185"
# [10,] "Westmont Office 24410-\rASI:LOC:24410"
# [11,] "Weymouth Re&c Site-\rCMP_46437"
# [12,] "White And Lavendar Pest\rContro-ASI:CMP:10299"
# [13,] "Inc-ASI:CMP:10307"
# [14,] "Wild Game Innovations Llc-\rASI:CMP:10318"
# [15,] "Wilfong Food & Gas Llc-\rASI:CMP:10323"
# [16,] "Wilkins Township-\rASI:CMP:13833"
# [17,] "William Sather-\rASI:PER:10346"
# [18,] "William Shoemaker-ab:99368"
#
# [[59]]
#       [,1]                     [,2]
#  [1,] "Suppliers Not Imported" ""
#  [2,] "Interface ID"           "Import Action"
#  [3,] ""                       ""
#  [4,] "9665"                   "UPDATE"
#  [5,] "9510"                   "UPDATE"
#  [6,] "9274"                   "UPDATE"
#  [7,] "9594"                   "UPDATE"
#  [8,] "9632"                   "UPDATE"
#  [9,] "9909"                   "UPDATE"
# [10,] "9399"                   "UPDATE"
# [11,] "9312"                   "UPDATE"
# [12,] "9974"                   "UPDATE"
# [13,] "9273"                   "UPDATE"
# [14,] "9277"                   "UPDATE"
# [15,] "9922"                   "UPDATE"
# [16,] "10156"                  "UPDATE"
# [17,] "10042"                  "UPDATE"
# [18,] "10194"                  "UPDATE"
# [19,] "9296"                   "UPDATE"
#       [,3]
#  [1,] ""
#  [2,] "Supplier"
#  [3,] "ab:99368"
#  [4,] "William Wimmer-\rASI:PER:20554"
#  [5,] "Williamson Yard\rFacilities-CMP_52708"
#  [6,] "Wilmington Office 775-\rLOC_775"
#  [7,] "Win-R Insulation"
#  [8,] "Woodside 05N LP-\rab:94353"
#  [9,] "World Class Demolition\rCorp-ab:56329"
# [10,] "Wyoming S&P-\rASI:CMP:10440"
# [11,] "Yardley Office 23344-\rASI:LOC:23344"
# [12,] "York Risk Services-\rab:97024"
# [13,] "Yvehfe Valadez-\rPER_20010"
# [14,] "Yvonne Albanez-\rPER_22706"
# [15,] "ZZZSTANISLAUS"
# [16,] "Zaina Thabet-\rASI:PER:14286"
# [17,] "de maximus\rEnvironmental\rRemediation Fund\rAccount-ab:57824"
# [18,] "insured unknown -\r14EP0942-\rMMK:CMP:461"
# [19,] "insured unknown -\r14EP1453-\rMMK:CMP:491"
#       [,4]              [,5]                             [,6]
#  [1,] ""                ""                               ""
#  [2,] "Supplier Number" "Rejection Reason"               "Attribute"
#  [3,] ""                ""                               ""
#  [4,] ""                "The value provided is invalid." "VENDOR_NAME"
#  [5,] ""                "The value provided is invalid." "VENDOR_NAME"
#  [6,] ""                "The value provided is invalid." "VENDOR_NAME"
#  [7,] ""                "The value provided is invalid." "VENDOR_NAME"
#  [8,] ""                "The value provided is invalid." "VENDOR_NAME"
#  [9,] ""                "The value provided is invalid." "VENDOR_NAME"
# [10,] ""                "The value provided is invalid." "VENDOR_NAME"
# [11,] ""                "The value provided is invalid." "VENDOR_NAME"
# [12,] ""                "The value provided is invalid." "VENDOR_NAME"
# [13,] ""                "The value provided is invalid." "VENDOR_NAME"
# [14,] ""                "The value provided is invalid." "VENDOR_NAME"
# [15,] ""                "The value provided is invalid." "VENDOR_NAME"
# [16,] ""                "The value provided is invalid." "VENDOR_NAME"
# [17,] ""                "The value provided is invalid." "VENDOR_NAME"
# [18,] ""                "The value provided is invalid." "VENDOR_NAME"
# [19,] ""                "The value provided is invalid." "VENDOR_NAME"
#       [,7]
#  [1,] ""
#  [2,] "Value"
#  [3,] ""
#  [4,] "William Wimmer-\rASI:PER:20554"
#  [5,] "Williamson Yard Facilities-\rCMP_52708"
#  [6,] "Wilmington Office 775-\rLOC_775"
#  [7,] "Win-R Insulation"
#  [8,] "Woodside 05N LP-ab:94353"
#  [9,] "World Class Demolition Corp-\rab:56329"
# [10,] "Wyoming S&P-\rASI:CMP:10440"
# [11,] "Yardley Office 23344-\rASI:LOC:23344"
# [12,] "York Risk Services-ab:97024"
# [13,] "Yvehfe Valadez-PER_20010"
# [14,] "Yvonne Albanez-PER_22706"
# [15,] "ZZZSTANISLAUS"
# [16,] "Zaina Thabet-ASI:PER:14286"
# [17,] "de maximus Environmental\rRemediation Fund Account-\rab:57824"
# [18,] "insured unknown - 14EP0942-\rMMK:CMP:461"
# [19,] "insured unknown - 14EP1453-\rMMK:CMP:491"
#
# [[60]]
#      [,1]                              [,2]
# [1,] "Suppliers Not Imported"          ""
# [2,] "Interface ID"                    "Import Action"
# [3,] "9642"                            "UPDATE"
# [4,] "9739"                            "UPDATE"
# [5,] "9435"                            "UPDATE"
# [6,] "9328"                            "UPDATE"
# [7,] "9924"                            "UPDATE"
# [8,] "Total Suppliers Not Imported999" ""
#      [,3]                                        [,4]
# [1,] ""                                          ""
# [2,] "Supplier"                                  "Supplier Number"
# [3,] "insured unknown -\r28EP0297-\rMMK:CMP:583" ""
# [4,] "insured unknown -\r28EP0570-\rMMK:CMP:585" ""
# [5,] "insured unknown -\r4SG03724-\rMMK:CMP:713" ""
# [6,] "insured unknown -\rASD03746-\rMMK:CMP:735" ""
# [7,] "insured unknown -\rGMV00053-\rMMK:CMP:801" ""
# [8,] ""                                          ""
#      [,5]                             [,6]
# [1,] ""                               ""
# [2,] "Rejection Reason"               "Attribute"
# [3,] "The value provided is invalid." "VENDOR_NAME"
# [4,] "The value provided is invalid." "VENDOR_NAME"
# [5,] "The value provided is invalid." "VENDOR_NAME"
# [6,] "The value provided is invalid." "VENDOR_NAME"
# [7,] "The value provided is invalid." "VENDOR_NAME"
# [8,] ""                               ""
#      [,7]
# [1,] ""
# [2,] "Value"
# [3,] "insured unknown - 28EP0297-\rMMK:CMP:583"
# [4,] "insured unknown - 28EP0570-\rMMK:CMP:585"
# [5,] "insured unknown - 4SG03724-\rMMK:CMP:713"
# [6,] "insured unknown -\rASD03746-MMK:CMP:735"
# [7,] "insured unknown -\rGMV00053-MMK:CMP:801"
# [8,] ""

# %%
page_1 = pdf_content[1]
page_1 = page_1 %>% data.frame()
page_1
# Out:
#    X1                     X2
# 1  Suppliers Not Imported
# 2  Interface ID           Import Action
# 3  9936                   UPDATE
# 4  9848                   UPDATE
# 5  9628                   UPDATE
# 6  9891                   UPDATE
# 7  9618                   UPDATE
# 8  9763                   UPDATE
# 9  9640                   UPDATE
# 10 9528                   UPDATE
# 11 9938                   UPDATE
# 12 9345                   UPDATE
# 13 9748                   UPDATE
# 14 10071                  UPDATE
# 15 9578                   UPDATE
# 16 10107                  UPDATE
#    X3
# 1
# 2  Supplier
# 3  1 Retail Investments\rSales Team In Southern\rCalifornia Inc-\rASI:CMP:9476
# 4  1131 Thurow-\rCMP_52251
# 5  1228 Harding Avenue-\rCMP_43179
# 6  1304 S Roxbury Drive\rLLC-ab:91422
# 7  14929 Lone Butte Road-\rCMP_50714
# 8  1507 Watson Boulevard-\rCMP_54905
# 9  1561-81 Kennedy Blvd.\r& 265 Gates Avenue-\rCMP_50626
# 10 2121-CMP_52224
# 11 2257 Akr Wadsworth\rRoad-CMP_55028
# 12 226 Wyckoff Avenue-\rCMP_42047
# 13 2347 Canton Highway-\rCMP_54902
# 14 2nd Avenue & 1st Street\rService Station-\rCMP_53819
# 15 300 & 500 East Truxton\rAve.-CMP_47839
# 16 3000 Houston Street\rDevelopment LLC-\rab:95653
#    X4              X5                             X6
# 1
# 2  Supplier Number Rejection Reason               Attribute
# 3                  The value provided is invalid. VENDOR_NAME
# 4                  The value provided is invalid. VENDOR_NAME
# 5                  The value provided is invalid. VENDOR_NAME
# 6                  The value provided is invalid. VENDOR_NAME
# 7                  The value provided is invalid. VENDOR_NAME
# 8                  The value provided is invalid. VENDOR_NAME
# 9                  The value provided is invalid. VENDOR_NAME
# 10                 The value provided is invalid. VENDOR_NAME
# 11                 The value provided is invalid. VENDOR_NAME
# 12                 The value provided is invalid. VENDOR_NAME
# 13                 The value provided is invalid. VENDOR_NAME
# 14                 The value provided is invalid. VENDOR_NAME
# 15                 The value provided is invalid. VENDOR_NAME
# 16                 The value provided is invalid. VENDOR_NAME
#    X7
# 1
# 2  Value
# 3  1 Retail Investments Sales\rTeam In Southern California\rInc-ASI:CMP:9476
# 4  1131 Thurow-CMP_52251
# 5  1228 Harding Avenue-\rCMP_43179
# 6  1304 S Roxbury Drive LLC-\rab:91422
# 7  14929 Lone Butte Road-\rCMP_50714
# 8  1507 Watson Boulevard-\rCMP_54905
# 9  1561-81 Kennedy Blvd. & 265\rGates Avenue-CMP_50626
# 10 2121-CMP_52224
# 11 2257 Akr Wadsworth Road-\rCMP_55028
# 12 226 Wyckoff Avenue-\rCMP_42047
# 13 2347 Canton Highway-\rCMP_54902
# 14 2nd Avenue & 1st Street\rService Station-CMP_53819
# 15 300 & 500 East Truxton Ave.-\rCMP_47839
# 16 3000 Houston Street\rDevelopment LLC-ab:95653

# %%
page_1_t = page_1[-c(1,2),]
drops <- c("X1","X2","X4","X6")
page_1_t  <- page_1_t[ , !(names(page_1_t) %in% drops)]
page_1_t
# Out:
#    X3
# 3  1 Retail Investments\rSales Team In Southern\rCalifornia Inc-\rASI:CMP:9476
# 4  1131 Thurow-\rCMP_52251
# 5  1228 Harding Avenue-\rCMP_43179
# 6  1304 S Roxbury Drive\rLLC-ab:91422
# 7  14929 Lone Butte Road-\rCMP_50714
# 8  1507 Watson Boulevard-\rCMP_54905
# 9  1561-81 Kennedy Blvd.\r& 265 Gates Avenue-\rCMP_50626
# 10 2121-CMP_52224
# 11 2257 Akr Wadsworth\rRoad-CMP_55028
# 12 226 Wyckoff Avenue-\rCMP_42047
# 13 2347 Canton Highway-\rCMP_54902
# 14 2nd Avenue & 1st Street\rService Station-\rCMP_53819
# 15 300 & 500 East Truxton\rAve.-CMP_47839
# 16 3000 Houston Street\rDevelopment LLC-\rab:95653
#    X5
# 3  The value provided is invalid.
# 4  The value provided is invalid.
# 5  The value provided is invalid.
# 6  The value provided is invalid.
# 7  The value provided is invalid.
# 8  The value provided is invalid.
# 9  The value provided is invalid.
# 10 The value provided is invalid.
# 11 The value provided is invalid.
# 12 The value provided is invalid.
# 13 The value provided is invalid.
# 14 The value provided is invalid.
# 15 The value provided is invalid.
# 16 The value provided is invalid.
#    X7
# 3  1 Retail Investments Sales\rTeam In Southern California\rInc-ASI:CMP:9476
# 4  1131 Thurow-CMP_52251
# 5  1228 Harding Avenue-\rCMP_43179
# 6  1304 S Roxbury Drive LLC-\rab:91422
# 7  14929 Lone Butte Road-\rCMP_50714
# 8  1507 Watson Boulevard-\rCMP_54905
# 9  1561-81 Kennedy Blvd. & 265\rGates Avenue-CMP_50626
# 10 2121-CMP_52224
# 11 2257 Akr Wadsworth Road-\rCMP_55028
# 12 226 Wyckoff Avenue-\rCMP_42047
# 13 2347 Canton Highway-\rCMP_54902
# 14 2nd Avenue & 1st Street\rService Station-CMP_53819
# 15 300 & 500 East Truxton Ave.-\rCMP_47839
# 16 3000 Houston Street\rDevelopment LLC-ab:95653
